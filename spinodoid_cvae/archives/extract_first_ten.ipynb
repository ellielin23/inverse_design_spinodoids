# %%
import numpy as np
from utils.data_utils.load_data import load_dataset

# === Config ===
DATA_PATH = "data/partition_by_theta/large_dataset_augmented.csv"
SAVE_PATH = "C_true_first10.npy"
N_ENTRIES = 10

# === Load dataset ===
P_all, S_all, C_all = load_dataset(DATA_PATH)  # C_all shape: (N, 3, 3, 3, 3)

# === Select first N_ENTRIES tensors ===
C_true_first10 = C_all[:N_ENTRIES]  # shape: (10, 3, 3, 3, 3)

# === Save to .npy file ===
np.save(SAVE_PATH, C_true_first10)
print(f"✅ Saved first {N_ENTRIES} C_true tensors to '{SAVE_PATH}'")
# Out:
# ✅ Saved first 10 C_true tensors to 'C_true_first10.npy'
