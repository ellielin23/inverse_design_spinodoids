# %%
import pandas as pd
df = pd.read_csv("data/partition_by_theta/theta_001.csv")
print(df.shape)
print(df.head())
# Out:
# (7000, 27)
#                id       rho  theta1  theta2     theta3        C1        C2  \
# 0  lamel_000001_2  0.316749     0.0     0.0  73.904340  0.088048  0.028013
# 1  lamel_000002_2  0.916205     0.0     0.0  47.964660  1.122071  0.450230
# 2  lamel_000003_2  0.729786     0.0     0.0  66.837710  0.679152  0.240181
# 3  lamel_000004_2  0.928405     0.0     0.0  58.081158  1.145957  0.466497
# 4  lamel_000005_2  0.806869     0.0     0.0  44.393570  0.877624  0.322537
#
#          C3        C4        C5  ...       C13       C14       C15       C16  \
# 0  0.024142  0.002840 -0.000908  ...  0.000409 -0.000391 -0.000946  0.060238
# 1  0.415412 -0.000372  0.003020  ... -0.000150  0.001225  0.001091  0.670595
# 2  0.218561  0.003434 -0.001945  ... -0.000218 -0.002144 -0.002728  0.434142
# 3  0.446781 -0.001013  0.001069  ...  0.000098  0.000230  0.001183  0.679564
# 4  0.257637 -0.001328  0.001087  ...  0.000085 -0.000904 -0.001814  0.552675
#
# ...
